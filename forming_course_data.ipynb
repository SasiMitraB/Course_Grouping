# %%
import numpy as np
import pandas as pd
import pprint
import random

# %% [markdown]
# # Code to check credit limit
#
# change the file path in pd.read_excel()

# %%
import pandas as pd

# Load the responses
responses = pd.read_excel("feedback_form_responses.xlsx")

# Initialize an empty list to store the indices of rows to keep
rows_to_keep = []

emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])

# Loop through each person's course choices
for index, (email, person_choice) in enumerate(zip(emails, choices)):
    person_choice = [x.strip() for x in person_choice.split(',')]
    
    # Remove specific courses
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    
    # Calculate total credits
    credits = 0
    for course in person_choice:
        credits += int(course[-1])  # Assuming the credit is the last character of the course string
    
    # If total credits are less than or equal to 25, mark the row to keep
    if credits <= 25:
        rows_to_keep.append(index)

# Filter the DataFrame to keep only the rows with total credits <= 25
filtered_responses = responses.iloc[rows_to_keep]

# Save the filtered DataFrame to a new Excel file
filtered_responses.to_excel("filtered_feedback_form_responses.xlsx", index=False)

filtered_responses
# Out:
#                   Timestamp  \
# 0   2024-07-23 17:28:02.839
# 1   2024-07-23 13:48:46.245
# 2   2024-07-23 13:50:40.352
# 3   2024-07-23 13:51:31.307
# 4   2024-07-23 13:53:17.589
# ..                      ...
# 250 2024-07-24 20:25:51.062
# 251 2024-07-24 20:28:31.176
# 252 2024-07-24 20:32:38.878
# 253 2024-07-24 20:50:21.111
# 254 2024-07-24 20:54:13.874
#
#                                          Email Address  \
# 0         kamath_20221075@students.iisertirupati.ac.in
# 1        kishore_20221082@students.iisertirupati.ac.in
# 2      devashish_20221043@students.iisertirupati.ac.in
# 3         bhavna_20221027@students.iisertirupati.ac.in
# 4          harsh_20221060@students.iisertirupati.ac.in
# ..                                                 ...
# 250       hanson_20221058@students.iisertirupati.ac.in
# 251  divyadarshini_20221047@students.iisertirupati....
# 252  sethulakshminair211102@students.iisertirupati....
# 253     anugraha_20221014@students.iisertirupati.ac.in
# ...

# %%
# Load the responses
responses = pd.read_excel("feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])

# Loop through each person's course choices
for email, person_choice in zip(emails, choices):
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    credits = 0
    for course in person_choice:
        credits += int(course[-1])  # Assuming the credit is the last character of the course string
    if credits > 25:
        print("-----")
        print(f"Email: {email}")
        print(f"Total Credits: {credits}")
        #print(f"Courses: {person_choice}")
# Out:
# -----
# Email: shamilmuhammad211086@students.iisertirupati.ac.in
# Total Credits: 56
# -----
# Email: pritikaraj211043@students.iisertirupati.ac.in
# Total Credits: 26
# -----
# Email: godarani211045@students.iisertirupati.ac.in
# Total Credits: 27
# -----
# Email: ashishranjan211019@students.iisertirupati.ac.in
# Total Credits: 27
# -----
# Email: karamzennisha211030@students.iisertirupati.ac.in
# Total Credits: 27
# -----
# Email: jigyasha_20221069@students.iisertirupati.ac.in
# Total Credits: 27

# %% [markdown]
# # Code to check ML and 22 batch people

# %%
# Load the responses
responses = pd.read_excel("feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])

# Loop through each person's course choices
for email, person_choice in zip(emails, choices):
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    
    if "_2022" in email and 'BIO434/734; CHM434/734; IDC434; ECS434/734; PHY434/734; CSA434/734; HSS434/734 Machine Learning (Data Science I) 4' in person_choice:
        print(email)

# %%
seventh_sem_only_courses = """BIO412/712 Animal Developmental Biology 4 
BIO413/713 Big Data in Biology 4 
BIO415/ BDS415 Programming for Data Science 4 
BIO416/716; CHM415 Biophysical Chemistry 4 
BIO417/717 Advanced Ecology 4 
BIO433/733 Plant stress biology for sustainable agriculture 4
BIO434/734; CHM434/734; IDC434; ECS434/734; PHY434/734; CSA434/734; HSS434/734 Machine Learning (Data Science-I) 4 
BIO435/735 Infection Biology I 4 
BIO436/736 Experimental Biology Lab I 4 
BIO714 Communicating Biology 2 
BIO715 Biodiversity Conservation and Sustainability 4 
CHM411/711 Molecular Symmetry and Spectroscopy 4
CHM412/712 Medicinal Chemistry 4
CHM413/713 Bioinorganic Chemistry 4
CHM414/714 Transition Metal Chemistry 4
CHM416/716; PHY411/711 Statistical Mechanics-II 4
CHM417/717 Chemistry of d- and f-Block Elements 4
CHM432/732; PHY432/732 Material Science 4
CHM433/733 Organic Spectroscopy 4
MTH411 Fields and Galois Theory 4
MTH412 Functional Analysis 4
MTH413 Introduction to Algebraic Topology 4
MTH414 Ordinary Differential Equations 4
MTH416 Probability Theory 4 
MTH611 Algebra I 4
MTH612 Analysis I 4
MTH613 Topology I 4
PHY413/713 Atomic & Molecular Physics 4
PHY415 Advanced Physics Lab III 4
PHY416/716 Experimental Methods in Physics 4
PHY417/717 Computational Methods in Physics 4
PHY433/733 Quantum Field Theory 4
HSS439/739 Complex Systems 3
ECS411/711 Atmospheric Thermodynamics and Cloud Physics 4
ECS412/712 Advanced Mineral Science 4
ECS413/713 Economic Geology 4
ECS414/714 Advanced Seismology 3
ECS439/739; PHY439/739; HSS439/739  Complex Systems 3"""

seventh_sem_only_courses = seventh_sem_only_courses.split("\n")
seventh_sem_only_courses = [ course.strip() for course in seventh_sem_only_courses]

# Load the responses
responses = pd.read_excel("feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])

# Loop through each person's course choices
for email, person_choice in zip(emails, choices):
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    
    for course_to_check in seventh_sem_only_courses:
        if course_to_check in person_choice and "_2022" in email:
            print(email)
            print(course_to_check)

# %%
# Load the responses
responses = pd.read_excel("feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])

course_to_check = 'HSS413 Scientific Entrepreneurship 3'

print(course_to_check)

# Loop through each person's course choices
for email, person_choice in zip(emails, choices):
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    
    if course_to_check in person_choice:
        print(email)
# Out:
# HSS413 Scientific Entrepreneurship 3
# shamilmuhammad211086@students.iisertirupati.ac.in
# gitika_20221054@students.iisertirupati.ac.in
# ashithanizar211146@students.iisertirupati.ac.in
# dineshkumar211152@students.iisertirupati.ac.in
# vinit_20221164@students.iisertirupati.ac.in
# mithankumargr211053@students.iisertirupati.ac.in
# suryendhusajan211063@students.iisertirupati.ac.in
# payal211071@students.iisertirupati.ac.in
# tagore_20221149@students.iisertirupati.ac.in
# anugraha_20221014@students.iisertirupati.ac.in

# %% [markdown]
# # Code to check how many students per course

# %%
responses = pd.read_excel("feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])
subjects = []

for person_choice in choices:
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    subjects.extend(person_choice)

subjects = set(subjects)

subject_count = {}
for subject in subjects:
    count = 0
    if "MTH" not in subject:
        pass
    for person_choice in choices:
        if subject in person_choice:
            count += 1
    subject_count[subject] = count

subject_count
# Out:
# {'PHY341/641 Fluid Dynamics 3': 6,
#  'CHM315; HSS315 Forensic Science 4': 32,
#  'CHM433/733 Organic Spectroscopy 4': 22,
#  'HSS411 Intellectual Property Rights (IPR) 3': 8,
#  'CHM311/611 Quantum Chemistry I 4': 19,
#  'Biophysical Chemistry 4': 5,
#  'CHM312/612 Physical Organic Chemistry 4': 27,
#  'BIO417/717 Advanced Ecology 4': 7,
#  'PHY311/611 Classical Mechanics II 4': 37,
#  'CHM314/614 Solid State Chemistry 4': 31,
#  'BIO415/ BDS415 Programming for Data Science 4': 19,
#  'BIO315/615 Molecular Plant Physiology 4': 53,
#  'MTH412 Functional Analysis 4': 7,
#  'PHY413/713 Atomic & Molecular Physics 4': 20,
#  'BIO319/619 Elements of Structural Biology 4': 9,
#  'MTH333 Indian Mathematics and Astronomy 2': 4,
#  'CHM432/732; PHY432/732 Material Science 4': 17,
#  'BIO412/712 Animal Developmental Biology 4': 47,
#  'MTH413 Introduction to Algebraic Topology 4': 10,
# ...

# %%
course_interelations = {}

for subject in subject_count:
    common_courses = {}
    
    for other_subject in subject_count:
        if subject != other_subject:
            common_courses[other_subject] = 0
            for person_choice in choices:
                if subject in person_choice and other_subject in person_choice:
                    common_courses[other_subject] += 1
    course_interelations[subject] = common_courses


pprint.pprint(course_interelations)
# Out:
# {'BIO311/611 Immunology 4': {'BIO313/613 Evolution 4': 48,
#                              'BIO314/614 Neurobiology 4': 20,
#                              'BIO315/615 Molecular Plant Physiology 4': 48,
#                              'BIO318/618 Genetics 4': 45,
#                              'BIO319/619 Elements of Structural Biology 4': 8,
#                              'BIO331/631 Cancer Biology 4': 25,
#                              'BIO412/712 Animal Developmental Biology 4': 3,
#                              'BIO413/713 Big Data in Biology 4': 5,
#                              'BIO415/ BDS415 Programming for Data Science 4': 2,
#                              'BIO417/717 Advanced Ecology 4': 1,
#                              'BIO433/733 Plant stress biology for sustainable agriculture 4': 0,
#                              'BIO434/734; CHM434/734; IDC434; ECS434/734; PHY434/734; CSA434/734; HSS434/734 Machine Learning (Data Science I) 4': 1,
# ...

# %%
course_interelations = {}

for subject in subject_count:
    common_courses = {}
    
    for other_subject in subject_count:
        if subject != other_subject:
            common_courses[other_subject] = 0
            for person_choice in choices:
                if subject in person_choice and other_subject in person_choice:
                    common_courses[other_subject] += 1
    course_interelations[subject] = common_courses


pprint.pprint(course_interelations)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the dictionary to a DataFrame
df = pd.DataFrame(course_interelations)

# Fill NaN values with 0 (if any)
df = df.fillna(0)

# Generate the heatmap
plt.figure(figsize=(30, 30))
heatmap = sns.heatmap(df, annot=True, cmap='YlGnBu', cbar=True, linewidths=.5)

# Set titles and labels
plt.title('Course Interrelations Heatmap')
plt.xlabel('Courses')
plt.ylabel('Courses')

# Show the heatmap
plt.show()

# To save the heatmap as an image
plt.savefig('course_interrelations_heatmap.png')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

responses = pd.read_excel("filtered_feedback_form_responses.xlsx")
emails = responses['Email Address']
choices = list(responses['Courses that I plan to take in the upcoming semester'])
subjects = []

for person_choice in choices:
    person_choice = [x.strip() for x in person_choice.split(',')]
    if "BIO339/639" in person_choice:
        person_choice.remove("BIO339/639")
    if "BIO416/716" in person_choice:
        person_choice.remove("BIO416/716")
    subjects.extend(person_choice)

subjects = set(subjects)

subject_count = {}
for subject in subjects:
    count = 0
    if "MTH" not in subject:
        pass
    for person_choice in choices:
        if subject in person_choice:
            count += 1
    subject_count[subject] = count

course_interelations = {}

for subject in subject_count:
    common_courses = {}
    
    for other_subject in subject_count:
        common_courses[other_subject] = 0
        for person_choice in choices:
            if subject in person_choice and other_subject in person_choice:
                common_courses[other_subject] += 1
    course_interelations[subject] = common_courses



# Convert the dictionary to a DataFrame
df = pd.DataFrame(course_interelations)

# Fill NaN values with 0 (if any)
df = df.fillna(0)

df.to_excel("Course_interrelations.xlsx")

df
# Out:
#                                                    PHY341/641 Fluid Dynamics 3  \
# PHY341/641 Fluid Dynamics 3                                                  6
# CHM315; HSS315 Forensic Science 4                                            0
# CHM433/733 Organic Spectroscopy 4                                            0
# HSS411 Intellectual Property Rights (IPR) 3                                  0
# CHM311/611 Quantum Chemistry I 4                                             0
# ...                                                                        ...
# ECS313 Introduction to Atmospheric Science 3                                 0
# MTH311 Groups and Rings 4                                                    0
# CHM417/717 Chemistry of d- and f-Block Elements 4                            0
# ECS413/713 Economic Geology 4                                                0
# PHY313 Statistical Mechanics I 4                                             4
#
# ...

# %%
course_interelations = {}

for subject in subject_count:
    if "MTH" in subject:
        common_courses = {}
        
        for other_subject in subject_count:
            if "MTH" in other_subject:
                if subject != other_subject:
                    common_courses[other_subject] = 0
                    for person_choice in choices:
                        if subject in person_choice and other_subject in person_choice:
                            common_courses[other_subject] += 1
        course_interelations[subject] = common_courses


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the dictionary to a DataFrame
df = pd.DataFrame(course_interelations)

# Fill NaN values with 0 (if any)
df = df.fillna(0)

# Generate the heatmap
plt.figure(figsize=(15, 15))
heatmap = sns.heatmap(df, annot=True, cmap='YlGnBu', cbar=True, linewidths=.5)

# Set titles and labels
plt.title('Course Interrelations Heatmap')
plt.xlabel('Courses')
plt.ylabel('Courses')

# Show the heatmap
plt.show()
